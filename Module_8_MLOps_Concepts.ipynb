# %% [markdown]
# <a href="https://colab.research.google.com/github/Pattiecodes/DataCamp_As.AIEng/blob/main/Module_8_MLOps_Concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# --- Module 8 Starts here ---

# %% [markdown]
# Module 8 has no code section.

# %% [markdown]
# # MLOPs Principles

# %% [markdown]
# ![image.png](data:image/png;base64,...)
