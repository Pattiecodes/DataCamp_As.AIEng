# %% [markdown]
# <a href="https://colab.research.google.com/github/Pattiecodes/DataCamp_As.AIEng/blob/main/Module_13_Monitoring_ML_Concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # --- Module Start ---

# %% [markdown]
# # Monitoring Performance
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Root Cause Analysis
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Issue Resolution
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Scenario: Model Predictions Fail
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Covariate Shift
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Guaranteed Negative Impacts
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Production Data (Ground Truth - Instant)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Production Data (Ground Truth - Delayed)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Production Data (Ground Truth - Absent)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # CBPE
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # DLE
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
